# %% [markdown]
# # SQL Запросы

# %% [markdown]
# `SELECT * FROM users;`

# %% [markdown]
# ![image.png](attachment:a39e54ce-2474-4cf4-9aa9-ea40d6471c0c.png)

# %% [markdown]
# `SELECT * FROM Trainers;`

# %% [markdown]
# ![image.png](attachment:31398d7c-4b7a-454f-b550-42a9b95bea36.png)

# %% [markdown]
# `SELECT * FROM Workouts;`

# %% [markdown]
# ![image.png](attachment:944a8894-6099-45ba-870e-5aa3a4b30a25.png)

# %% [markdown]
# `SELECT * FROM Bookings;`

# %% [markdown]
# ![image.png](attachment:ecc0d68e-5dc1-4564-b68f-ab06cc592417.png)

# %% [markdown]
# `SELECT * FROM Reviews;`

# %% [markdown]
# ![image.png](attachment:a8af9b62-aedd-4257-ac37-02c0643619b9.png)

# %% [markdown]
# `SELECT * FROM Users` <br>
# `
# WHERE name LIKE 'A%'`;

# %% [markdown]
# ![image.png](attachment:29d912b0-aa14-4eb0-86f0-35bfaee66559.png)

# %% [markdown]
# SELECT * FROM Trainers
# WHERE qualification = 'Certified Personal Trainer' OR qualification = 'CrossFit Trainer';

# %% [markdown]
# ![image.png](attachment:4c88753d-aa65-4fc2-9d70-a040d6179705.png)

# %% [markdown]
# SELECT * FROM Workouts
# ORDER BY date DESC;

# %% [markdown]
# ![image.png](attachment:f59d43a1-fe53-4996-9061-967c0d297a4b.png)

# %% [markdown]
# SELECT * FROM Bookings
# WHERE booking_date BETWEEN '2024-10-01' AND '2024-10-31';

# %% [markdown]
# ![image.png](attachment:9390809c-8fd2-4904-bb66-7de8d03d7e61.png)

# %% [markdown]
# SELECT workout_id, AVG(rating) AS average_rating
# FROM Reviews
# GROUP BY workout_id;

# %% [markdown]
# ![image.png](attachment:7b5eeba1-4bad-4500-8ed4-e24a809356b7.png)

# %% [markdown]
# SELECT workout_id, AVG(rating) AS average_rating
# FROM Reviews
# GROUP BY workout_id
# HAVING AVG(rating) > 4;

# %% [markdown]
# ![image.png](attachment:64fd6aa8-d0eb-4d18-b3e5-1d9eb50aad0d.png)

# %% [markdown]
# SELECT Users.name AS user_name, Workouts.work_name AS workout_name, Bookings.booking_date
# FROM Bookings
# JOIN Users ON Bookings.user_id = Users.user_id
# JOIN Workouts ON Bookings.workout_id = Workouts.workout_id;

# %% [markdown]
# ![image.png](attachment:6f0e80e4-04cc-4e9a-afe1-765833fb8491.png)

# %% [markdown]
# `SELECT name
# FROM Users
# WHERE user_id IN (
#     SELECT user_id
#     FROM Reviews
#     WHERE rating <` 3
# );

# %% [markdown]
# ![image.png](attachment:948894b0-d156-458c-8d2e-18c4d2e4d980.png)
